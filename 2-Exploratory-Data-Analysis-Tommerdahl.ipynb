# %% [markdown]
# # Exploratory Data Analysis
# We are going to find some more obvious patterns with EDA before identifying the hidden patterns with machines learning (ML) techniques. We are going to look at the following for each file:
# Most common words - find these and create word clouds

# %% [markdown]
# ## Most common words

# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('dtm_to.pkl')
data = data.transpose()
data.head()
# Out:
#              AJC1.xml  AJC2.xml  AVW1.xml  AVW2.xml  BDO1.xml  BDO2.xml  \
# able                0         1         0         0         0         0
# abracadabra         0         0         0         0         0         0
# accident            0         0         0         0         0         0
# ache                0         0         0         0         0         0
# aches               0         0         0         0         0         0
#
#              CDH1.xml  CMC1.xml  CMC2.xml  ECB1.xml  ...  OMS1.xml  OMS2.xml  \
# able                0         0         0         2  ...         0         0
# abracadabra         0         0         0         0  ...         2         0
# accident            0         0         0         0  ...         0         0
# ache                0        17         0         0  ...         0         0
# aches               0         1         0         0  ...         0         0
#
#              RMB1.xml  RMB2.xml  SAU1.xml  SAU2.xml  SC1.xml  SC2.xml  \
# able                0         0         0         0        0        0
# abracadabra         0         0         0         0        0        0
# accident            0         0         0         0        0        0
# ache                0         0         0         2        0        0
# aches               0         0         0         0        0        0
#
#              WJAW1.xml  WJAW2.xml
# able                 0          0
# abracadabra          0          0
# accident             0          0
# ache                 0          0
# aches                0          0
#
# [5 rows x 44 columns]

# %%
# Find the top 30 words said by each file
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'AJC1.xml': [('yeah', 125),
#   ('oh', 70),
#   ('okay', 65),
#   ('like', 41),
#   ('thats', 40),
#   ('ooh', 36),
#   ('got', 35),
#   ('did', 26),
#   ('whats', 26),
#   ('look', 24),
#   ('think', 23),
#   ('dont', 22),
#   ('wanna', 21),
#   ('im', 21),
#   ('come', 21),
#   ('know', 20),
#   ('theres', 20),
#   ('um', 19),
#   ('does', 19),
#   ('lets', 19),
#   ('umm', 17),
#   ('rubbish', 17),
#   ('mom', 16),
#   ('knock', 16),
#   ('yes', 16),
#   ('wow', 16),
#   ('hm', 15),
#   ('play', 15),
#   ('going', 14),
#   ('daniel', 14)],
#  'AJC2.xml': [('yeah', 127),
#   ('oh', 61),
#   ('like', 49),
#   ('okay', 33),
#   ('wanna', 33),
#   ('look', 31),
#   ('wow', 28),
#   ('think', 27),
#   ('mom', 27),
#   ('ooh', 26),
#   ('got', 26),
#   ('dont', 23),
#   ('car', 21),
#   ('come', 21),
#   ('did', 20),
#   ('um', 20),
#   ('thats', 18),
#   ('hafta', 18),
#   ('does', 18),
#   ('play', 17),
#   ('lets', 16),
#   ('im', 16),
#   ('youre', 15),
#   ('drink', 15),
#   ('going', 15),
#   ('good', 15),
#   ('hes', 15),
#   ('way', 14),
#   ('monkey', 14),
#   ('apple', 14)],
#  'AVW1.xml': [('oh', 54),
#   ('did', 45),
#   ('got', 29),
#   ('okay', 27),
#   ('plate', 25),
#   ('im', 22),
#   ('going', 22),
#   ('pretend', 22),
#   ('cream', 21),
#   ('ice', 20),
#   ('bit', 18),
#   ('yeah', 16),
#   ('look', 16),
#   ('erm', 15),
#   ('think', 15),
#   ('like', 15),
#   ('grapes', 14),
#   ('thats', 13),
#   ('suki', 13),
#   ('big', 13),
#   ('ive', 13),
#   ('bed', 13),
#   ('having', 13),
#   ('toilet', 12),
#   ('shes', 12),
#   ('whats', 11),
#   ('hot', 11),
#   ('remember', 11),
#   ('drink', 11),
#   ('tea', 11)],
#  'AVW2.xml': [('la', 62),
#   ('oh', 43),
#   ('okay', 41),
#   ('dog', 25),
#   ('got', 25),
#   ('going', 19),
#   ('yeah', 18),
#   ('im', 16),
#   ('did', 16),
#   ('xxx', 15),
#   ('thing', 14),
#   ('think', 13),
#   ('giddy', 13),
#   ('having', 13),
#   ('yesterday', 12),
#   ('grapes', 12),
#   ('angel', 12),
#   ('lets', 12),
#   ('princess', 11),
#   ('yes', 10),
#   ('big', 10),
#   ('look', 10),
#   ('just', 9),
#   ('ive', 9),
#   ('little', 9),
#   ('dragon', 9),
#   ('apple', 9),
#   ('like', 9),
#   ('thats', 9),
#   ('tea', 8)],
#  'BDO1.xml': [('look', 22),
#   ('dont', 18),
#   ('whats', 16),
#   ('yeah', 15),
#   ('thats', 15),
#   ('like', 15),
#   ('oh', 14),
#   ('xxx', 13),
#   ('mum', 13),
#   ('helicopter', 9),
#   ('going', 9),
#   ('grapes', 9),
#   ('cheese', 9),
#   ('engine', 8),
#   ('think', 8),
#   ('got', 7),
#   ('big', 7),
#   ('doing', 6),
#   ('just', 6),
#   ('pull', 6),
#   ('open', 6),
#   ('mm', 6),
#   ('funny', 6),
#   ('cow', 6),
#   ('theres', 5),
#   ('pretend', 5),
#   ('hot', 5),
#   ('juice', 5),
#   ('needs', 5),
#   ('hes', 5)],
#  'BDO2.xml': [('yeah', 40),
#   ('xxx', 36),
#   ('mum', 22),
#   ('going', 20),
#   ('oh', 18),
#   ('trot', 17),
#   ('eat', 17),
#   ('tree', 16),
#   ('shes', 14),
#   ('dont', 14),
#   ('theyre', 13),
#   ('hes', 13),
#   ('needs', 12),
#   ('cake', 12),
#   ('whats', 11),
#   ('does', 11),
#   ('squirrel', 10),
#   ('cat', 10),
#   ('little', 10),
#   ('doesnt', 9),
#   ('got', 9),
#   ('just', 9),
#   ('know', 8),
#   ('come', 8),
#   ('look', 8),
#   ('having', 8),
#   ('make', 8),
#   ('thats', 8),
#   ('house', 7),
#   ('theres', 7)],
#  'CDH1.xml': [('dont', 42),
#   ('thats', 39),
#   ('want', 31),
#   ('going', 28),
#   ('oh', 27),
#   ('yeah', 26),
#   ('like', 26),
#   ('come', 25),
#   ('okay', 24),
#   ('look', 23),
#   ('eat', 21),
#   ('hello', 20),
#   ('little', 20),
#   ('got', 20),
#   ('house', 19),
#   ('think', 19),
#   ('thankyou', 19),
#   ('whats', 18),
#   ('yes', 18),
#   ('goats', 17),
#   ('monkey', 17),
#   ('bye', 17),
#   ('wanna', 16),
#   ('allgone', 16),
#   ('charlie', 15),
#   ('theres', 15),
#   ('hes', 15),
#   ('lets', 15),
#   ('gonna', 12),
#   ('does', 12)],
#  'CMC1.xml': [('yeah', 74),
#   ('house', 45),
#   ('thats', 32),
#   ('whats', 29),
#   ('oh', 28),
#   ('um', 27),
#   ('wheres', 25),
#   ('gone', 23),
#   ('got', 22),
#   ('belly', 21),
#   ('did', 20),
#   ('theres', 18),
#   ('lets', 17),
#   ('ache', 17),
#   ('yes', 16),
#   ('open', 16),
#   ('come', 15),
#   ('like', 15),
#   ('boy', 13),
#   ('mummy', 13),
#   ('dont', 13),
#   ('little', 13),
#   ('im', 12),
#   ('teddy', 12),
#   ('tea', 12),
#   ('car', 12),
#   ('bye', 12),
#   ('cake', 11),
#   ('play', 11),
#   ('look', 11)],
#  'CMC2.xml': [('yeah', 64),
#   ('oh', 52),
#   ('plate', 48),
#   ('xxx', 44),
#   ('like', 42),
#   ('wheres', 36),
#   ('thats', 34),
#   ('cake', 33),
#   ('dont', 32),
#   ('daddy', 29),
#   ('tea', 25),
#   ('cup', 23),
#   ('look', 20),
#   ('whats', 20),
#   ('um', 18),
#   ('theres', 17),
#   ('okay', 17),
#   ('bye', 17),
#   ('thankyou', 16),
#   ('hello', 15),
#   ('yes', 14),
#   ('wanna', 14),
#   ('house', 14),
#   ('hm', 14),
#   ('lady', 13),
#   ('got', 13),
#   ('want', 13),
#   ('mum', 12),
#   ('phone', 11),
#   ('meow', 11)],
#  'ECB1.xml': [('oh', 40),
#   ('yeah', 39),
#   ('look', 31),
#   ('like', 28),
#   ('whats', 27),
#   ('thats', 25),
#   ('theres', 19),
#   ('yes', 18),
#   ('xxx', 17),
#   ('did', 17),
#   ('think', 13),
#   ('eat', 13),
#   ('erm', 13),
#   ('going', 12),
#   ('remember', 11),
#   ('right', 11),
#   ('want', 10),
#   ('okay', 9),
#   ('dont', 9),
#   ('shall', 9),
#   ('big', 9),
#   ('make', 9),
#   ('daddy', 9),
#   ('favorite', 9),
#   ('yum', 8),
#   ('good', 8),
#   ('little', 8),
#   ('got', 8),
#   ('know', 8),
#   ('juice', 8)],
#  'ECB2.xml': [('oh', 43),
#   ('thats', 35),
#   ('whats', 23),
#   ('yeah', 23),
#   ('okay', 22),
#   ('look', 22),
#   ('going', 17),
#   ('like', 17),
#   ('road', 17),
#   ('right', 16),
#   ('mummy', 16),
#   ('theres', 16),
#   ('yes', 14),
#   ('lets', 14),
#   ('dont', 13),
#   ('got', 12),
#   ('did', 12),
#   ('want', 11),
#   ('works', 10),
#   ('started', 10),
#   ('food', 9),
#   ('theyre', 9),
#   ('xxx', 9),
#   ('eat', 8),
#   ('shall', 7),
#   ('erm', 7),
#   ('crash', 7),
#   ('yesterday', 7),
#   ('hafta', 7),
#   ('isnt', 7)],
#  'ECG1.xml': [('yeah', 69),
#   ('whats', 24),
#   ('erm', 23),
#   ('oh', 19),
#   ('like', 16),
#   ('shall', 15),
#   ('did', 14),
#   ('good', 13),
#   ('going', 12),
#   ('got', 12),
#   ('eat', 11),
#   ('cream', 11),
#   ('ice', 11),
#   ('thats', 11),
#   ('blue', 11),
#   ('bubbly', 10),
#   ('girl', 10),
#   ('juice', 10),
#   ('green', 10),
#   ('xxx', 9),
#   ('box', 9),
#   ('look', 8),
#   ('bed', 8),
#   ('okay', 8),
#   ('pink', 7),
#   ('orange', 7),
#   ('big', 7),
#   ('make', 7),
#   ('play', 6),
#   ('bit', 6)],
#  'ECG2.xml': [('yeah', 53),
#   ('oh', 28),
#   ('did', 22),
#   ('like', 22),
#   ('whats', 20),
#   ('round', 17),
#   ('erm', 14),
#   ('going', 13),
#   ('way', 11),
#   ('wheres', 11),
#   ('got', 11),
#   ('thats', 11),
#   ('girl', 10),
#   ('dont', 10),
#   ('good', 9),
#   ('xxx', 9),
#   ('big', 9),
#   ('does', 7),
#   ('juice', 7),
#   ('holiday', 7),
#   ('bubbly', 6),
#   ('wrong', 6),
#   ('helicopter', 6),
#   ('cake', 6),
#   ('know', 6),
#   ('look', 6),
#   ('bit', 6),
#   ('hungry', 5),
#   ('peas', 5),
#   ('eat', 5)],
#  'ELG1.xml': [('yeah', 77),
#   ('thats', 57),
#   ('whats', 36),
#   ('look', 34),
#   ('like', 34),
#   ('oh', 29),
#   ('shall', 28),
#   ('theres', 27),
#   ('got', 25),
#   ('know', 20),
#   ('called', 19),
#   ('going', 16),
#   ('erm', 15),
#   ('plate', 14),
#   ('did', 13),
#   ('round', 13),
#   ('eat', 13),
#   ('xxx', 12),
#   ('goes', 12),
#   ('thankyou', 12),
#   ('house', 12),
#   ('mummy', 11),
#   ('cut', 11),
#   ('does', 10),
#   ('wow', 9),
#   ('wheres', 9),
#   ('tea', 9),
#   ('big', 9),
#   ('make', 9),
#   ('want', 9)],
#  'ELG2.xml': [('yeah', 49),
#   ('shall', 31),
#   ('dont', 30),
#   ('did', 23),
#   ('look', 19),
#   ('oh', 18),
#   ('wanna', 15),
#   ('come', 15),
#   ('going', 13),
#   ('play', 13),
#   ('whats', 12),
#   ('poo', 12),
#   ('playgroup', 12),
#   ('little', 12),
#   ('thats', 12),
#   ('xxx', 12),
#   ('like', 12),
#   ('callum', 11),
#   ('mm', 10),
#   ('cut', 10),
#   ('wine', 10),
#   ('okay', 9),
#   ('toast', 8),
#   ('big', 8),
#   ('trousers', 8),
#   ('toilet', 8),
#   ('mummy', 8),
#   ('harry', 8),
#   ('drink', 8),
#   ('grapes', 8)],
#  'FC1.xml': [('yeah', 83),
#   ('oh', 39),
#   ('got', 38),
#   ('thats', 33),
#   ('look', 33),
#   ('like', 31),
#   ('think', 25),
#   ('know', 25),
#   ('dont', 23),
#   ('going', 22),
#   ('mummy', 20),
#   ('birthday', 18),
#   ('right', 18),
#   ('whats', 17),
#   ('does', 17),
#   ('erm', 17),
#   ('shall', 16),
#   ('big', 16),
#   ('good', 15),
#   ('okay', 14),
#   ('did', 14),
#   ('isnt', 13),
#   ('hes', 12),
#   ('theres', 11),
#   ('xxx', 11),
#   ('wine', 11),
#   ('didnt', 11),
#   ('bit', 11),
#   ('round', 10),
#   ('make', 10)],
#  'FC2.xml': [('yeah', 49),
#   ('oh', 42),
#   ('thats', 30),
#   ('like', 28),
#   ('going', 28),
#   ('got', 25),
#   ('dont', 24),
#   ('right', 24),
#   ('nellie', 23),
#   ('okay', 21),
#   ('look', 20),
#   ('big', 19),
#   ('know', 18),
#   ('think', 17),
#   ('didnt', 15),
#   ('whats', 14),
#   ('ive', 13),
#   ('does', 13),
#   ('round', 13),
#   ('way', 13),
#   ('im', 12),
#   ('did', 11),
#   ('ah', 11),
#   ('nellies', 11),
#   ('shall', 11),
#   ('xxx', 11),
#   ('wanna', 11),
#   ('teapot', 10),
#   ('tower', 10),
#   ('fly', 10)],
#  'FMW1.xml': [('oh', 60),
#   ('look', 52),
#   ('yeah', 48),
#   ('thats', 47),
#   ('like', 45),
#   ('got', 30),
#   ('know', 29),
#   ('going', 27),
#   ('whats', 26),
#   ('xxx', 26),
#   ('theres', 22),
#   ('did', 22),
#   ('dont', 21),
#   ('mummy', 19),
#   ('think', 19),
#   ('does', 18),
#   ('right', 17),
#   ('faye', 17),
#   ('pizza', 17),
#   ('little', 15),
#   ('want', 14),
#   ('mm', 13),
#   ('tea', 12),
#   ('house', 12),
#   ('im', 12),
#   ('yes', 11),
#   ('ones', 11),
#   ('wanna', 11),
#   ('bedroom', 11),
#   ('isnt', 10)],
#  'FMW2.xml': [('oh', 50),
#   ('going', 40),
#   ('thats', 39),
#   ('yeah', 36),
#   ('xxx', 36),
#   ('dont', 30),
#   ('like', 23),
#   ('wanna', 22),
#   ('think', 21),
#   ('does', 19),
#   ('know', 18),
#   ('zoo', 18),
#   ('look', 17),
#   ('big', 15),
#   ('yes', 15),
#   ('ice', 15),
#   ('nice', 13),
#   ('bed', 13),
#   ('good', 11),
#   ('got', 11),
#   ('mm', 11),
#   ('okay', 11),
#   ('erm', 11),
#   ('park', 11),
#   ('cream', 11),
#   ('sit', 10),
#   ('theres', 10),
#   ('right', 10),
#   ('whats', 9),
#   ('did', 9)],
#  'JH1.xml': [('yeah', 75),
#   ('xxx', 32),
#   ('want', 22),
#   ('come', 19),
#   ('hafta', 17),
#   ('hop', 11),
#   ('neenaw', 10),
#   ('cat', 9),
#   ('mum', 9),
#   ('got', 9),
#   ('nanny', 8),
#   ('yes', 8),
#   ('mummy', 7),
#   ('turtle', 7),
#   ('oh', 7),
#   ('rabbit', 6),
#   ('need', 6),
#   ('engine', 6),
#   ('dig', 6),
#   ('wanna', 6),
#   ('eat', 6),
#   ('look', 6),
#   ('nut', 5),
#   ('erm', 5),
#   ('like', 5),
#   ('home', 5),
#   ('birt', 5),
#   ('know', 5),
#   ('dont', 5),
#   ('helicopter', 4)],
#  'Jessica1.xml': [('cat', 30),
#   ('hes', 28),
#   ('right', 21),
#   ('whats', 20),
#   ('farm', 19),
#   ('house', 19),
#   ('yeah', 17),
#   ('goes', 16),
#   ('xxx', 15),
#   ('moo', 15),
#   ('look', 15),
#   ('play', 11),
#   ('just', 11),
#   ('know', 11),
#   ('got', 11),
#   ('tractor', 11),
#   ('cow', 11),
#   ('dont', 10),
#   ('doing', 10),
#   ('thats', 9),
#   ('sure', 9),
#   ('gone', 8),
#   ('small', 8),
#   ('wheres', 8),
#   ('come', 8),
#   ('think', 8),
#   ('animals', 7),
#   ('wanna', 7),
#   ('like', 7),
#   ('theres', 7)],
#  'Jessica2.xml': [('think', 26),
#   ('dont', 22),
#   ('look', 21),
#   ('yes', 20),
#   ('hes', 19),
#   ('like', 18),
#   ('whats', 17),
#   ('thats', 15),
#   ('going', 15),
#   ('doing', 14),
#   ('xxx', 14),
#   ('cat', 14),
#   ('theyre', 14),
#   ('tractor', 13),
#   ('got', 13),
#   ('fit', 12),
#   ('youre', 11),
#   ('tell', 11),
#   ('box', 11),
#   ('yeah', 11),
#   ('just', 11),
#   ('chick', 11),
#   ('know', 11),
#   ('right', 11),
#   ('car', 10),
#   ('house', 10),
#   ('does', 9),
#   ('really', 9),
#   ('wanna', 9),
#   ('oh', 9)],
#  'LP1.xml': [('yeah', 32),
#   ('xxx', 24),
#   ('dont', 20),
#   ('yum', 20),
#   ('like', 19),
#   ('oh', 19),
#   ('got', 17),
#   ('look', 16),
#   ('whats', 16),
#   ('mouth', 14),
#   ('ice', 14),
#   ('thankyou', 13),
#   ('pink', 12),
#   ('squirrel', 12),
#   ('thats', 12),
#   ('going', 12),
#   ('did', 11),
#   ('house', 11),
#   ('bear', 11),
#   ('erm', 10),
#   ('nice', 10),
#   ('does', 9),
#   ('know', 9),
#   ('hes', 9),
#   ('theres', 9),
#   ('cream', 9),
#   ('yes', 8),
#   ('plate', 8),
#   ('aswell', 8),
#   ('wanna', 7)],
#  'LP2.xml': [('yeah', 26),
#   ('house', 22),
#   ('oh', 22),
#   ('dont', 21),
#   ('dog', 17),
#   ('going', 15),
#   ('hafta', 14),
#   ('cat', 13),
#   ('live', 13),
#   ('xxx', 12),
#   ('whats', 12),
#   ('big', 12),
#   ('slide', 11),
#   ('mum', 11),
#   ('look', 11),
#   ('fit', 11),
#   ('doggy', 11),
#   ('animals', 10),
#   ('im', 10),
#   ('thats', 10),
#   ('think', 10),
#   ('woof', 10),
#   ('just', 10),
#   ('okay', 9),
#   ('like', 9),
#   ('cow', 9),
#   ('round', 9),
#   ('hes', 9),
#   ('pull', 8),
#   ('little', 8)],
#  'MCC1.xml': [('xxx', 28),
#   ('oh', 26),
#   ('rabbit', 21),
#   ('got', 19),
#   ('look', 18),
#   ('dont', 18),
#   ('yeah', 18),
#   ('thats', 17),
#   ('yes', 17),
#   ('yellow', 16),
#   ('going', 16),
#   ('poo', 14),
#   ('order', 13),
#   ('come', 13),
#   ('lets', 13),
#   ('right', 13),
#   ('theres', 12),
#   ('little', 11),
#   ('maybe', 11),
#   ('milk', 10),
#   ('im', 9),
#   ('maddie', 9),
#   ('ambulance', 9),
#   ('okay', 9),
#   ('want', 9),
#   ('doing', 9),
#   ('mummy', 8),
#   ('school', 8),
#   ('house', 8),
#   ('think', 8)],
#  'MCC2.xml': [('yes', 38),
#   ('lets', 28),
#   ('shall', 9),
#   ('ill', 7),
#   ('im', 7),
#   ('dont', 6),
#   ('celery', 6),
#   ('xxx', 6),
#   ('yeah', 6),
#   ('eat', 6),
#   ('wanna', 5),
#   ('mum', 5),
#   ('play', 5),
#   ('got', 4),
#   ('cake', 4),
#   ('come', 4),
#   ('theres', 4),
#   ('thats', 3),
#   ('order', 3),
#   ('bacon', 3),
#   ('think', 3),
#   ('mm', 3),
#   ('know', 3),
#   ('try', 3),
#   ('big', 3),
#   ('mummy', 3),
#   ('leave', 3),
#   ('house', 3),
#   ('away', 3),
#   ('going', 3)],
#  'MEH1.xml': [('oh', 37),
#   ('got', 33),
#   ('look', 31),
#   ('rabbit', 30),
#   ('yeah', 22),
#   ('hello', 20),
#   ('like', 19),
#   ('whats', 18),
#   ('erm', 17),
#   ('dont', 17),
#   ('mary', 16),
#   ('xxx', 15),
#   ('eat', 12),
#   ('horsie', 12),
#   ('know', 11),
#   ('friends', 11),
#   ('think', 11),
#   ('thats', 10),
#   ('people', 10),
#   ('jack', 10),
#   ('ah', 10),
#   ('going', 9),
#   ('little', 9),
#   ('yes', 9),
#   ('evie', 9),
#   ('make', 9),
#   ('woof', 9),
#   ('poo', 8),
#   ('want', 8),
#   ('shall', 8)],
#  'MEH2.xml': [('oh', 44),
#   ('got', 34),
#   ('erm', 29),
#   ('look', 26),
#   ('yeah', 23),
#   ('dog', 23),
#   ('going', 22),
#   ('little', 22),
#   ('doggy', 19),
#   ('thats', 19),
#   ('like', 18),
#   ('want', 16),
#   ('dont', 16),
#   ('yes', 16),
#   ('know', 16),
#   ('does', 14),
#   ('food', 14),
#   ('need', 13),
#   ('woof', 13),
#   ('big', 13),
#   ('poorly', 12),
#   ('horse', 12),
#   ('dogs', 12),
#   ('xxx', 12),
#   ('doctor', 11),
#   ('hello', 11),
#   ('squirrel', 11),
#   ('play', 11),
#   ('eat', 11),
#   ('fly', 11)],
#  'MH1.xml': [('yeah', 49),
#   ('thats', 29),
#   ('look', 27),
#   ('oh', 26),
#   ('xxx', 24),
#   ('play', 22),
#   ('dont', 22),
#   ('think', 16),
#   ('like', 14),
#   ('erm', 14),
#   ('theyre', 14),
#   ('did', 13),
#   ('need', 13),
#   ('youre', 12),
#   ('isnt', 11),
#   ('okay', 11),
#   ('theres', 11),
#   ('got', 11),
#   ('pizza', 10),
#   ('girl', 10),
#   ('wedding', 10),
#   ('lets', 10),
#   ('come', 10),
#   ('cat', 9),
#   ('baby', 9),
#   ('wanna', 9),
#   ('er', 9),
#   ('bed', 9),
#   ('hotel', 9),
#   ('room', 9)],
#  'MH2.xml': [('yeah', 72),
#   ('going', 24),
#   ('xxx', 22),
#   ('dont', 20),
#   ('like', 20),
#   ('know', 18),
#   ('isnt', 18),
#   ('think', 18),
#   ('didnt', 17),
#   ('erm', 16),
#   ('did', 16),
#   ('thats', 16),
#   ('youre', 16),
#   ('oh', 14),
#   ('want', 13),
#   ('lettuce', 13),
#   ('does', 12),
#   ('tea', 12),
#   ('look', 12),
#   ('got', 12),
#   ('today', 12),
#   ('dummy', 12),
#   ('play', 10),
#   ('time', 9),
#   ('just', 9),
#   ('went', 9),
#   ('yes', 9),
#   ('yesterday', 9),
#   ('mummy', 8),
#   ('car', 8)],
#  'Megan1.xml': [('did', 31),
#   ('yeah', 28),
#   ('whats', 25),
#   ('got', 20),
#   ('yes', 20),
#   ('dont', 18),
#   ('oh', 18),
#   ('okay', 17),
#   ('thats', 17),
#   ('does', 15),
#   ('house', 15),
#   ('im', 14),
#   ('look', 13),
#   ('xxx', 12),
#   ('youre', 11),
#   ('car', 11),
#   ('like', 11),
#   ('good', 10),
#   ('making', 10),
#   ('wheels', 10),
#   ('need', 10),
#   ('gonna', 10),
#   ('goes', 9),
#   ('road', 8),
#   ('big', 8),
#   ('play', 8),
#   ('didnt', 7),
#   ('stuff', 7),
#   ('ill', 7),
#   ('theyre', 7)],
#  'Megan2.xml': [('yeah', 36),
#   ('im', 26),
#   ('thats', 25),
#   ('gonna', 24),
#   ('okay', 24),
#   ('look', 19),
#   ('shall', 19),
#   ('xxx', 18),
#   ('dont', 17),
#   ('oh', 16),
#   ('like', 16),
#   ('boat', 14),
#   ('got', 14),
#   ('whats', 13),
#   ('did', 12),
#   ('yes', 11),
#   ('big', 10),
#   ('play', 10),
#   ('going', 10),
#   ('youre', 9),
#   ('tell', 9),
#   ('goes', 9),
#   ('think', 9),
#   ('telling', 8),
#   ('hhh', 8),
#   ('gotta', 8),
#   ('make', 8),
#   ('know', 8),
#   ('cat', 7),
#   ('cow', 7)],
#  'OH1.xml': [('look', 32),
#   ('know', 18),
#   ('whats', 16),
#   ('oh', 15),
#   ('okay', 14),
#   ('shall', 11),
#   ('like', 11),
#   ('yeah', 10),
#   ('play', 10),
#   ('wanna', 8),
#   ('cup', 8),
#   ('tea', 8),
#   ('thats', 8),
#   ('things', 8),
#   ('think', 8),
#   ('rub', 7),
#   ('dont', 6),
#   ('did', 6),
#   ('cheese', 6),
#   ('thankyou', 6),
#   ('ill', 6),
#   ('lets', 6),
#   ('lots', 6),
#   ('xxx', 5),
#   ('got', 5),
#   ('breakfast', 5),
#   ('theres', 5),
#   ('just', 5),
#   ('teapot', 4),
#   ('goes', 4)],
#  'OH2.xml': [('xxx', 20),
#   ('shall', 18),
#   ('yeah', 13),
#   ('look', 10),
#   ('okay', 9),
#   ('bed', 8),
#   ('know', 7),
#   ('juice', 7),
#   ('yes', 6),
#   ('got', 6),
#   ('sugar', 6),
#   ('cat', 5),
#   ('mum', 5),
#   ('nice', 5),
#   ('rabbit', 4),
#   ('theres', 4),
#   ('want', 4),
#   ('tea', 4),
#   ('yum', 4),
#   ('plate', 4),
#   ('plates', 4),
#   ('play', 4),
#   ('need', 4),
#   ('howabout', 4),
#   ('big', 3),
#   ('im', 3),
#   ('baby', 3),
#   ('bigger', 3),
#   ('erm', 3),
#   ('awake', 3)],
#  'OMS1.xml': [('got', 26),
#   ('dont', 20),
#   ('like', 18),
#   ('know', 18),
#   ('oh', 17),
#   ('did', 17),
#   ('time', 13),
#   ('want', 11),
#   ('wheres', 10),
#   ('juice', 10),
#   ('look', 9),
#   ('ice', 9),
#   ('xxx', 9),
#   ('car', 8),
#   ('alright', 8),
#   ('does', 7),
#   ('im', 7),
#   ('bed', 7),
#   ('going', 7),
#   ('okay', 7),
#   ('cream', 7),
#   ('come', 7),
#   ('big', 7),
#   ('good', 6),
#   ('tea', 6),
#   ('mat', 6),
#   ('play', 6),
#   ('orange', 6),
#   ('dog', 6),
#   ('neenaw', 6)],
#  'OMS2.xml': [('alright', 19),
#   ('got', 12),
#   ('going', 11),
#   ('thats', 11),
#   ('oh', 8),
#   ('come', 7),
#   ('tea', 7),
#   ('okay', 7),
#   ('thankyou', 6),
#   ('isnt', 6),
#   ('little', 6),
#   ('drink', 5),
#   ('cream', 5),
#   ('hes', 5),
#   ('ice', 5),
#   ('im', 5),
#   ('dont', 5),
#   ('like', 5),
#   ('big', 4),
#   ('doing', 4),
#   ('look', 4),
#   ('juice', 4),
#   ('ive', 4),
#   ('whats', 4),
#   ('bits', 3),
#   ('know', 3),
#   ('want', 3),
#   ('carrot', 3),
#   ('bit', 3),
#   ('table', 3)],
#  'RMB1.xml': [('yeah', 56),
#   ('yum', 31),
#   ('oh', 18),
#   ('like', 16),
#   ('dont', 14),
#   ('look', 13),
#   ('theres', 13),
#   ('whats', 13),
#   ('bit', 12),
#   ('xxx', 12),
#   ('gonna', 11),
#   ('bedroom', 11),
#   ('sandwich', 11),
#   ('tea', 11),
#   ('hey', 11),
#   ('bed', 10),
#   ('little', 10),
#   ('thats', 9),
#   ('know', 9),
#   ('box', 9),
#   ('lets', 9),
#   ('okay', 8),
#   ('girls', 8),
#   ('heres', 8),
#   ('fruit', 8),
#   ('mm', 8),
#   ('think', 8),
#   ('chop', 7),
#   ('come', 7),
#   ('theyre', 7)],
#  'RMB2.xml': [('yeah', 43),
#   ('oh', 34),
#   ('xxx', 31),
#   ('okay', 23),
#   ('look', 23),
#   ('like', 21),
#   ('heres', 18),
#   ('thats', 18),
#   ('dont', 17),
#   ('tree', 14),
#   ('need', 14),
#   ('ice', 12),
#   ('im', 12),
#   ('good', 12),
#   ('bit', 12),
#   ('theres', 12),
#   ('cream', 11),
#   ('fruit', 11),
#   ('whats', 11),
#   ('ill', 10),
#   ('eat', 10),
#   ('steak', 10),
#   ('hello', 10),
#   ('knight', 10),
#   ('going', 10),
#   ('needta', 9),
#   ('yes', 9),
#   ('house', 9),
#   ('mm', 9),
#   ('brave', 9)],
#  'SAU1.xml': [('oh', 38),
#   ('yeah', 25),
#   ('look', 24),
#   ('think', 19),
#   ('like', 16),
#   ('want', 15),
#   ('thats', 15),
#   ('cup', 13),
#   ('mummy', 13),
#   ('grapes', 13),
#   ('got', 13),
#   ('theres', 12),
#   ('house', 11),
#   ('sleep', 10),
#   ('yes', 10),
#   ('hey', 10),
#   ('dont', 10),
#   ('mm', 10),
#   ('eaten', 10),
#   ('cut', 9),
#   ('cake', 9),
#   ('plate', 9),
#   ('heres', 8),
#   ('need', 8),
#   ('know', 8),
#   ('rabbit', 7),
#   ('come', 7),
#   ('fit', 7),
#   ('xxx', 7),
#   ('ah', 7)],
#  'SAU2.xml': [('like', 33),
#   ('yeah', 30),
#   ('oh', 29),
#   ('got', 19),
#   ('mummy', 18),
#   ('just', 18),
#   ('come', 14),
#   ('dont', 14),
#   ('okay', 13),
#   ('baby', 13),
#   ('house', 12),
#   ('little', 12),
#   ('want', 11),
#   ('thats', 10),
#   ('going', 10),
#   ('wanna', 10),
#   ('look', 9),
#   ('girl', 9),
#   ('think', 9),
#   ('hafta', 8),
#   ('dinner', 8),
#   ('im', 8),
#   ('yes', 8),
#   ('hes', 8),
#   ('heres', 7),
#   ('bit', 7),
#   ('awe', 7),
#   ('xxx', 7),
#   ('crisps', 6),
#   ('open', 6)],
#  'SC1.xml': [('think', 19),
#   ('yeah', 17),
#   ('whats', 14),
#   ('tickle', 13),
#   ('going', 12),
#   ('like', 12),
#   ('got', 12),
#   ('ready', 11),
#   ('round', 11),
#   ('yes', 11),
#   ('time', 10),
#   ('im', 10),
#   ('chocolate', 10),
#   ('tea', 9),
#   ('theres', 9),
#   ('gonna', 9),
#   ('bigger', 8),
#   ('helicopter', 8),
#   ('hot', 8),
#   ('pink', 8),
#   ('did', 8),
#   ('little', 7),
#   ('ice', 7),
#   ('thats', 7),
#   ('called', 6),
#   ('erm', 6),
#   ('remember', 6),
#   ('breakfast', 6),
#   ('billy', 6),
#   ('cat', 6)],
#  'SC2.xml': [('going', 21),
#   ('got', 16),
#   ('plate', 15),
#   ('ice', 14),
#   ('im', 13),
#   ('mm', 11),
#   ('oh', 11),
#   ('whats', 10),
#   ('like', 10),
#   ('theres', 10),
#   ('food', 9),
#   ('cream', 9),
#   ('gonna', 9),
#   ('xxx', 8),
#   ('wanna', 8),
#   ('eat', 8),
#   ('tea', 8),
#   ('think', 7),
#   ('come', 7),
#   ('thats', 7),
#   ('wheres', 7),
#   ('lots', 7),
#   ('yeah', 7),
#   ('house', 6),
#   ('yes', 6),
#   ('things', 6),
#   ('thankyou', 5),
#   ('play', 5),
#   ('hide', 5),
#   ('creams', 5)],
#  'WJAW1.xml': [('look', 33),
#   ('thats', 33),
#   ('going', 32),
#   ('mom', 24),
#   ('yeah', 23),
#   ('okay', 22),
#   ('oh', 21),
#   ('whats', 20),
#   ('dont', 19),
#   ('play', 18),
#   ('like', 18),
#   ('think', 17),
#   ('xxx', 17),
#   ('helicopter', 15),
#   ('yes', 14),
#   ('did', 14),
#   ('didnt', 14),
#   ('wheres', 13),
#   ('got', 13),
#   ('theres', 12),
#   ('lets', 12),
#   ('know', 11),
#   ('want', 11),
#   ('land', 9),
#   ('cake', 9),
#   ('isnt', 9),
#   ('airport', 8),
#   ('ambulance', 8),
#   ('just', 8),
#   ('im', 8)],
#  'WJAW2.xml': [('yeah', 36),
#   ('mom', 35),
#   ('look', 29),
#   ('okay', 29),
#   ('lets', 23),
#   ('oh', 21),
#   ('dont', 20),
#   ('thats', 19),
#   ('just', 18),
#   ('yes', 18),
#   ('going', 18),
#   ('xxx', 15),
#   ('want', 15),
#   ('wheres', 14),
#   ('right', 11),
#   ('like', 11),
#   ('play', 11),
#   ('alright', 10),
#   ('think', 10),
#   ('good', 9),
#   ('make', 9),
#   ('bed', 9),
#   ('does', 9),
#   ('need', 9),
#   ('whats', 8),
#   ('got', 8),
#   ('big', 8),
#   ('isnt', 8),
#   ('theres', 8),
#   ('open', 8)]}

# %%
# Print the top 15 words said by each file
for file, top_words in top_dict.items():
    print(file)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# AJC1.xml
# yeah, oh, okay, like, thats, ooh, got, did, whats, look, think, dont, wanna, im
# ---
# AJC2.xml
# yeah, oh, like, okay, wanna, look, wow, think, mom, ooh, got, dont, car, come
# ---
# AVW1.xml
# oh, did, got, okay, plate, im, going, pretend, cream, ice, bit, yeah, look, erm
# ---
# AVW2.xml
# la, oh, okay, dog, got, going, yeah, im, did, xxx, thing, think, giddy, having
# ---
# BDO1.xml
# look, dont, whats, yeah, thats, like, oh, xxx, mum, helicopter, going, grapes, cheese, engine
# ---
# BDO2.xml
# yeah, xxx, mum, going, oh, trot, eat, tree, shes, dont, theyre, hes, needs, cake
# ---
# CDH1.xml
# dont, thats, want, going, oh, yeah, like, come, okay, look, eat, hello, little, got
# ---
# CMC1.xml
# yeah, house, thats, whats, oh, um, wheres, gone, got, belly, did, theres, lets, ache
# ---
# CMC2.xml
# yeah, oh, plate, xxx, like, wheres, thats, cake, dont, daddy, tea, cup, look, whats
# ---
# ECB1.xml
# oh, yeah, look, like, whats, thats, theres, yes, xxx, did, think, eat, erm, going
# ---
# ECB2.xml
# oh, thats, whats, yeah, okay, look, going, like, road, right, mummy, theres, yes, lets
# ---
# ECG1.xml
# yeah, whats, erm, oh, like, shall, did, good, going, got, eat, cream, ice, thats
# ---
# ECG2.xml
# yeah, oh, did, like, whats, round, erm, going, way, wheres, got, thats, girl, dont
# ---
# ELG1.xml
# yeah, thats, whats, look, like, oh, shall, theres, got, know, called, going, erm, plate
# ---
# ELG2.xml
# yeah, shall, dont, did, look, oh, wanna, come, going, play, whats, poo, playgroup, little
# ---
# FC1.xml
# yeah, oh, got, thats, look, like, think, know, dont, going, mummy, birthday, right, whats
# ---
# FC2.xml
# yeah, oh, thats, like, going, got, dont, right, nellie, okay, look, big, know, think
# ---
# FMW1.xml
# oh, look, yeah, thats, like, got, know, going, whats, xxx, theres, did, dont, mummy
# ---
# FMW2.xml
# oh, going, thats, yeah, xxx, dont, like, wanna, think, does, know, zoo, look, big
# ---
# JH1.xml
# yeah, xxx, want, come, hafta, hop, neenaw, cat, mum, got, nanny, yes, mummy, turtle
# ---
# Jessica1.xml
# cat, hes, right, whats, farm, house, yeah, goes, xxx, moo, look, play, just, know
# ---
# Jessica2.xml
# think, dont, look, yes, hes, like, whats, thats, going, doing, xxx, cat, theyre, tractor
# ---
# LP1.xml
# yeah, xxx, dont, yum, like, oh, got, look, whats, mouth, ice, thankyou, pink, squirrel
# ---
# LP2.xml
# yeah, house, oh, dont, dog, going, hafta, cat, live, xxx, whats, big, slide, mum
# ---
# MCC1.xml
# xxx, oh, rabbit, got, look, dont, yeah, thats, yes, yellow, going, poo, order, come
# ---
# MCC2.xml
# yes, lets, shall, ill, im, dont, celery, xxx, yeah, eat, wanna, mum, play, got
# ---
# MEH1.xml
# oh, got, look, rabbit, yeah, hello, like, whats, erm, dont, mary, xxx, eat, horsie
# ---
# MEH2.xml
# oh, got, erm, look, yeah, dog, going, little, doggy, thats, like, want, dont, yes
# ---
# MH1.xml
# yeah, thats, look, oh, xxx, play, dont, think, like, erm, theyre, did, need, youre
# ---
# MH2.xml
# yeah, going, xxx, dont, like, know, isnt, think, didnt, erm, did, thats, youre, oh
# ---
# Megan1.xml
# did, yeah, whats, got, yes, dont, oh, okay, thats, does, house, im, look, xxx
# ---
# Megan2.xml
# yeah, im, thats, gonna, okay, look, shall, xxx, dont, oh, like, boat, got, whats
# ---
# OH1.xml
# look, know, whats, oh, okay, shall, like, yeah, play, wanna, cup, tea, thats, things
# ---
# OH2.xml
# xxx, shall, yeah, look, okay, bed, know, juice, yes, got, sugar, cat, mum, nice
# ---
# OMS1.xml
# got, dont, like, know, oh, did, time, want, wheres, juice, look, ice, xxx, car
# ---
# OMS2.xml
# alright, got, going, thats, oh, come, tea, okay, thankyou, isnt, little, drink, cream, hes
# ---
# RMB1.xml
# yeah, yum, oh, like, dont, look, theres, whats, bit, xxx, gonna, bedroom, sandwich, tea
# ---
# RMB2.xml
# yeah, oh, xxx, okay, look, like, heres, thats, dont, tree, need, ice, im, good
# ---
# SAU1.xml
# oh, yeah, look, think, like, want, thats, cup, mummy, grapes, got, theres, house, sleep
# ---
# SAU2.xml
# like, yeah, oh, got, mummy, just, come, dont, okay, baby, house, little, want, thats
# ---
# SC1.xml
# think, yeah, whats, tickle, going, like, got, ready, round, yes, time, im, chocolate, tea
# ---
# SC2.xml
# going, got, plate, ice, im, mm, oh, whats, like, theres, food, cream, gonna, xxx
# ---
# WJAW1.xml
# look, thats, going, mom, yeah, okay, oh, whats, dont, play, like, think, xxx, helicopter
# ---
# WJAW2.xml
# yeah, mom, look, okay, lets, oh, dont, thats, just, yes, going, xxx, want, wheres
# ---

# %% [markdown]
# We can still see some meaningless words, even though we can create word cloud from this.
# So we should further remove more stop words.

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each file
words = []
for file in data.columns:
    top = [word for (word, count) in top_dict[file]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['yeah',
#  'oh',
#  'okay',
#  'like',
#  'thats',
#  'ooh',
#  'got',
#  'did',
#  'whats',
#  'look',
#  'think',
#  'dont',
#  'wanna',
#  'im',
#  'come',
#  'know',
#  'theres',
#  'um',
#  'does',
#  'lets',
#  'umm',
#  'rubbish',
#  'mom',
#  'knock',
#  'yes',
#  'wow',
#  'hm',
#  'play',
#  'going',
#  'daniel',
#  'yeah',
#  'oh',
#  'like',
#  'okay',
#  'wanna',
#  'look',
#  'wow',
#  'think',
#  'mom',
#  'ooh',
#  'got',
#  'dont',
#  'car',
#  'come',
#  'did',
#  'um',
#  'thats',
#  'hafta',
#  'does',
#  'play',
#  'lets',
#  'im',
#  'youre',
#  'drink',
#  'going',
#  'good',
#  'hes',
#  'way',
#  'monkey',
#  'apple',
#  'oh',
#  'did',
#  'got',
#  'okay',
#  'plate',
#  'im',
#  'going',
#  'pretend',
#  'cream',
#  'ice',
#  'bit',
#  'yeah',
#  'look',
#  'erm',
#  'think',
#  'like',
#  'grapes',
#  'thats',
#  'suki',
#  'big',
#  'ive',
#  'bed',
#  'having',
#  'toilet',
#  'shes',
#  'whats',
#  'hot',
#  'remember',
#  'drink',
#  'tea',
#  'la',
#  'oh',
#  'okay',
#  'dog',
#  'got',
#  'going',
#  'yeah',
#  'im',
#  'did',
#  'xxx',
#  'thing',
#  'think',
#  'giddy',
#  'having',
#  'yesterday',
#  'grapes',
#  'angel',
#  'lets',
#  'princess',
#  'yes',
#  'big',
#  'look',
#  'just',
#  'ive',
#  'little',
#  'dragon',
#  'apple',
#  'like',
#  'thats',
#  'tea',
#  'look',
#  'dont',
#  'whats',
#  'yeah',
#  'thats',
#  'like',
#  'oh',
#  'xxx',
#  'mum',
#  'helicopter',
#  'going',
#  'grapes',
#  'cheese',
#  'engine',
#  'think',
#  'got',
#  'big',
#  'doing',
#  'just',
#  'pull',
#  'open',
#  'mm',
#  'funny',
#  'cow',
#  'theres',
#  'pretend',
#  'hot',
#  'juice',
#  'needs',
#  'hes',
#  'yeah',
#  'xxx',
#  'mum',
#  'going',
#  'oh',
#  'trot',
#  'eat',
#  'tree',
#  'shes',
#  'dont',
#  'theyre',
#  'hes',
#  'needs',
#  'cake',
#  'whats',
#  'does',
#  'squirrel',
#  'cat',
#  'little',
#  'doesnt',
#  'got',
#  'just',
#  'know',
#  'come',
#  'look',
#  'having',
#  'make',
#  'thats',
#  'house',
#  'theres',
#  'dont',
#  'thats',
#  'want',
#  'going',
#  'oh',
#  'yeah',
#  'like',
#  'come',
#  'okay',
#  'look',
#  'eat',
#  'hello',
#  'little',
#  'got',
#  'house',
#  'think',
#  'thankyou',
#  'whats',
#  'yes',
#  'goats',
#  'monkey',
#  'bye',
#  'wanna',
#  'allgone',
#  'charlie',
#  'theres',
#  'hes',
#  'lets',
#  'gonna',
#  'does',
#  'yeah',
#  'house',
#  'thats',
#  'whats',
#  'oh',
#  'um',
#  'wheres',
#  'gone',
#  'got',
#  'belly',
#  'did',
#  'theres',
#  'lets',
#  'ache',
#  'yes',
#  'open',
#  'come',
#  'like',
#  'boy',
#  'mummy',
#  'dont',
#  'little',
#  'im',
#  'teddy',
#  'tea',
#  'car',
#  'bye',
#  'cake',
#  'play',
#  'look',
#  'yeah',
#  'oh',
#  'plate',
#  'xxx',
#  'like',
#  'wheres',
#  'thats',
#  'cake',
#  'dont',
#  'daddy',
#  'tea',
#  'cup',
#  'look',
#  'whats',
#  'um',
#  'theres',
#  'okay',
#  'bye',
#  'thankyou',
#  'hello',
#  'yes',
#  'wanna',
#  'house',
#  'hm',
#  'lady',
#  'got',
#  'want',
#  'mum',
#  'phone',
#  'meow',
#  'oh',
#  'yeah',
#  'look',
#  'like',
#  'whats',
#  'thats',
#  'theres',
#  'yes',
#  'xxx',
#  'did',
#  'think',
#  'eat',
#  'erm',
#  'going',
#  'remember',
#  'right',
#  'want',
#  'okay',
#  'dont',
#  'shall',
#  'big',
#  'make',
#  'daddy',
#  'favorite',
#  'yum',
#  'good',
#  'little',
#  'got',
#  'know',
#  'juice',
#  'oh',
#  'thats',
#  'whats',
#  'yeah',
#  'okay',
#  'look',
#  'going',
#  'like',
#  'road',
#  'right',
#  'mummy',
#  'theres',
#  'yes',
#  'lets',
#  'dont',
#  'got',
#  'did',
#  'want',
#  'works',
#  'started',
#  'food',
#  'theyre',
#  'xxx',
#  'eat',
#  'shall',
#  'erm',
#  'crash',
#  'yesterday',
#  'hafta',
#  'isnt',
#  'yeah',
#  'whats',
#  'erm',
#  'oh',
#  'like',
#  'shall',
#  'did',
#  'good',
#  'going',
#  'got',
#  'eat',
#  'cream',
#  'ice',
#  'thats',
#  'blue',
#  'bubbly',
#  'girl',
#  'juice',
#  'green',
#  'xxx',
#  'box',
#  'look',
#  'bed',
#  'okay',
#  'pink',
#  'orange',
#  'big',
#  'make',
#  'play',
#  'bit',
#  'yeah',
#  'oh',
#  'did',
#  'like',
#  'whats',
#  'round',
#  'erm',
#  'going',
#  'way',
#  'wheres',
#  'got',
#  'thats',
#  'girl',
#  'dont',
#  'good',
#  'xxx',
#  'big',
#  'does',
#  'juice',
#  'holiday',
#  'bubbly',
#  'wrong',
#  'helicopter',
#  'cake',
#  'know',
#  'look',
#  'bit',
#  'hungry',
#  'peas',
#  'eat',
#  'yeah',
#  'thats',
#  'whats',
#  'look',
#  'like',
#  'oh',
#  'shall',
#  'theres',
#  'got',
#  'know',
#  'called',
#  'going',
#  'erm',
#  'plate',
#  'did',
#  'round',
#  'eat',
#  'xxx',
#  'goes',
#  'thankyou',
#  'house',
#  'mummy',
#  'cut',
#  'does',
#  'wow',
#  'wheres',
#  'tea',
#  'big',
#  'make',
#  'want',
#  'yeah',
#  'shall',
#  'dont',
#  'did',
#  'look',
#  'oh',
#  'wanna',
#  'come',
#  'going',
#  'play',
#  'whats',
#  'poo',
#  'playgroup',
#  'little',
#  'thats',
#  'xxx',
#  'like',
#  'callum',
#  'mm',
#  'cut',
#  'wine',
#  'okay',
#  'toast',
#  'big',
#  'trousers',
#  'toilet',
#  'mummy',
#  'harry',
#  'drink',
#  'grapes',
#  'yeah',
#  'oh',
#  'got',
#  'thats',
#  'look',
#  'like',
#  'think',
#  'know',
#  'dont',
#  'going',
#  'mummy',
#  'birthday',
#  'right',
#  'whats',
#  'does',
#  'erm',
#  'shall',
#  'big',
#  'good',
#  'okay',
#  'did',
#  'isnt',
#  'hes',
#  'theres',
#  'xxx',
#  'wine',
#  'didnt',
#  'bit',
#  'round',
#  'make',
#  'yeah',
#  'oh',
#  'thats',
#  'like',
#  'going',
#  'got',
#  'dont',
#  'right',
#  'nellie',
#  'okay',
#  'look',
#  'big',
#  'know',
#  'think',
#  'didnt',
#  'whats',
#  'ive',
#  'does',
#  'round',
#  'way',
#  'im',
#  'did',
#  'ah',
#  'nellies',
#  'shall',
#  'xxx',
#  'wanna',
#  'teapot',
#  'tower',
#  'fly',
#  'oh',
#  'look',
#  'yeah',
#  'thats',
#  'like',
#  'got',
#  'know',
#  'going',
#  'whats',
#  'xxx',
#  'theres',
#  'did',
#  'dont',
#  'mummy',
#  'think',
#  'does',
#  'right',
#  'faye',
#  'pizza',
#  'little',
#  'want',
#  'mm',
#  'tea',
#  'house',
#  'im',
#  'yes',
#  'ones',
#  'wanna',
#  'bedroom',
#  'isnt',
#  'oh',
#  'going',
#  'thats',
#  'yeah',
#  'xxx',
#  'dont',
#  'like',
#  'wanna',
#  'think',
#  'does',
#  'know',
#  'zoo',
#  'look',
#  'big',
#  'yes',
#  'ice',
#  'nice',
#  'bed',
#  'good',
#  'got',
#  'mm',
#  'okay',
#  'erm',
#  'park',
#  'cream',
#  'sit',
#  'theres',
#  'right',
#  'whats',
#  'did',
#  'yeah',
#  'xxx',
#  'want',
#  'come',
#  'hafta',
#  'hop',
#  'neenaw',
#  'cat',
#  'mum',
#  'got',
#  'nanny',
#  'yes',
#  'mummy',
#  'turtle',
#  'oh',
#  'rabbit',
#  'need',
#  'engine',
#  'dig',
#  'wanna',
#  'eat',
#  'look',
#  'nut',
#  'erm',
#  'like',
#  'home',
#  'birt',
#  'know',
#  'dont',
#  'helicopter',
#  'cat',
#  'hes',
#  'right',
#  'whats',
#  'farm',
#  'house',
#  'yeah',
#  'goes',
#  'xxx',
#  'moo',
#  'look',
#  'play',
#  'just',
#  'know',
#  'got',
#  'tractor',
#  'cow',
#  'dont',
#  'doing',
#  'thats',
#  'sure',
#  'gone',
#  'small',
#  'wheres',
#  'come',
#  'think',
#  'animals',
#  'wanna',
#  'like',
#  'theres',
#  'think',
#  'dont',
#  'look',
#  'yes',
#  'hes',
#  'like',
#  'whats',
#  'thats',
#  'going',
#  'doing',
#  'xxx',
#  'cat',
#  'theyre',
#  'tractor',
#  'got',
#  'fit',
#  'youre',
#  'tell',
#  'box',
#  'yeah',
#  'just',
#  'chick',
#  'know',
#  'right',
#  'car',
#  'house',
#  'does',
#  'really',
#  'wanna',
#  'oh',
#  'yeah',
#  'xxx',
#  'dont',
#  'yum',
#  'like',
#  'oh',
#  'got',
#  'look',
#  'whats',
#  'mouth',
#  'ice',
#  'thankyou',
#  'pink',
#  'squirrel',
#  'thats',
#  'going',
#  'did',
#  'house',
#  'bear',
#  'erm',
#  'nice',
#  'does',
#  'know',
#  'hes',
#  'theres',
#  'cream',
#  'yes',
#  'plate',
#  'aswell',
#  'wanna',
#  'yeah',
#  'house',
#  'oh',
#  'dont',
#  'dog',
#  'going',
#  'hafta',
#  'cat',
#  'live',
#  'xxx',
#  'whats',
#  'big',
#  'slide',
#  'mum',
#  'look',
#  'fit',
#  'doggy',
#  'animals',
#  'im',
#  'thats',
#  'think',
#  'woof',
#  'just',
#  'okay',
#  'like',
#  'cow',
#  'round',
#  'hes',
#  'pull',
#  'little',
#  'xxx',
#  'oh',
#  'rabbit',
#  'got',
#  'look',
#  'dont',
#  'yeah',
#  'thats',
#  'yes',
#  'yellow',
#  'going',
#  'poo',
#  'order',
#  'come',
#  'lets',
#  'right',
#  'theres',
#  'little',
#  'maybe',
#  'milk',
#  'im',
#  'maddie',
#  'ambulance',
#  'okay',
#  'want',
#  'doing',
#  'mummy',
#  'school',
#  'house',
#  'think',
#  'yes',
#  'lets',
#  'shall',
#  'ill',
#  'im',
#  'dont',
#  'celery',
#  'xxx',
#  'yeah',
#  'eat',
#  'wanna',
#  'mum',
#  'play',
#  'got',
#  'cake',
#  'come',
#  'theres',
#  'thats',
#  'order',
#  'bacon',
#  'think',
#  'mm',
#  'know',
#  'try',
#  'big',
#  'mummy',
#  'leave',
#  'house',
#  'away',
#  'going',
#  'oh',
#  'got',
#  'look',
#  'rabbit',
#  'yeah',
#  'hello',
#  'like',
#  'whats',
#  'erm',
#  'dont',
#  'mary',
#  'xxx',
#  'eat',
#  'horsie',
#  'know',
#  'friends',
#  'think',
#  'thats',
#  'people',
#  'jack',
#  'ah',
#  'going',
#  'little',
#  'yes',
#  'evie',
#  'make',
#  'woof',
#  'poo',
#  'want',
#  'shall',
#  'oh',
#  'got',
#  'erm',
#  'look',
#  'yeah',
#  'dog',
#  'going',
#  'little',
#  'doggy',
#  'thats',
#  'like',
#  'want',
#  'dont',
#  'yes',
#  'know',
#  'does',
#  'food',
#  'need',
#  'woof',
#  'big',
#  'poorly',
#  'horse',
#  'dogs',
#  'xxx',
#  'doctor',
#  'hello',
#  'squirrel',
#  'play',
#  'eat',
#  'fly',
#  'yeah',
#  'thats',
#  'look',
#  'oh',
#  'xxx',
#  'play',
#  'dont',
#  'think',
#  'like',
#  'erm',
#  'theyre',
#  'did',
#  'need',
#  'youre',
#  'isnt',
#  'okay',
#  'theres',
#  'got',
#  'pizza',
#  'girl',
#  'wedding',
#  'lets',
#  'come',
#  'cat',
#  'baby',
#  'wanna',
#  'er',
#  'bed',
#  'hotel',
#  'room',
#  'yeah',
#  'going',
#  'xxx',
#  'dont',
#  'like',
#  'know',
#  'isnt',
#  'think',
#  'didnt',
#  'erm',
#  'did',
#  'thats',
#  'youre',
#  'oh',
#  'want',
#  'lettuce',
#  'does',
#  'tea',
#  'look',
#  'got',
#  'today',
#  'dummy',
#  'play',
#  'time',
#  'just',
#  'went',
#  'yes',
#  'yesterday',
#  'mummy',
#  'car',
#  'did',
#  'yeah',
#  'whats',
#  'got',
#  'yes',
#  'dont',
#  'oh',
#  'okay',
#  'thats',
#  'does',
#  'house',
#  'im',
#  'look',
#  'xxx',
#  'youre',
#  'car',
#  'like',
#  'good',
#  'making',
#  'wheels',
#  'need',
#  'gonna',
#  'goes',
#  'road',
#  'big',
#  'play',
#  'didnt',
#  'stuff',
#  'ill',
#  'theyre',
#  'yeah',
#  'im',
#  'thats',
#  'gonna',
#  'okay',
#  'look',
#  'shall',
#  'xxx',
#  'dont',
#  'oh',
#  'like',
#  'boat',
#  'got',
#  'whats',
#  'did',
#  'yes',
#  'big',
#  'play',
#  'going',
#  'youre',
#  'tell',
#  'goes',
#  'think',
#  'telling',
#  'hhh',
#  'gotta',
#  'make',
#  'know',
#  'cat',
#  'cow',
#  'look',
#  'know',
#  'whats',
#  'oh',
#  'okay',
#  'shall',
#  'like',
#  'yeah',
#  'play',
#  'wanna',
#  'cup',
#  'tea',
#  'thats',
#  'things',
#  'think',
#  'rub',
#  'dont',
#  'did',
#  'cheese',
#  'thankyou',
#  'ill',
#  'lets',
#  'lots',
#  'xxx',
#  'got',
#  'breakfast',
#  'theres',
#  'just',
#  'teapot',
#  'goes',
#  'xxx',
#  'shall',
#  'yeah',
#  'look',
#  'okay',
#  'bed',
#  'know',
#  'juice',
#  'yes',
#  'got',
#  ...]

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('yeah', 42),
#  ('thats', 41),
#  ('look', 41),
#  ('oh', 40),
#  ('like', 40),
#  ('got', 40),
#  ('dont', 37),
#  ('xxx', 37),
#  ('going', 34),
#  ('whats', 32),
#  ('think', 28),
#  ('okay', 27),
#  ('yes', 27),
#  ('theres', 26),
#  ('know', 25),
#  ('did', 24),
#  ('im', 20),
#  ('big', 20),
#  ('play', 18),
#  ('want', 18),
#  ('wanna', 17),
#  ('come', 17),
#  ('does', 17),
#  ('house', 17),
#  ('erm', 16),
#  ('little', 15),
#  ('tea', 14),
#  ('lets', 13),
#  ('eat', 13),
#  ('mummy', 12),
#  ('shall', 12),
#  ('hes', 11),
#  ('just', 11),
#  ('good', 10),
#  ('right', 10),
#  ('ice', 9),
#  ('mm', 9),
#  ('cat', 9),
#  ('wheres', 9),
#  ('cream', 8),
#  ('bit', 8),
#  ('bed', 8),
#  ('make', 8),
#  ('isnt', 8),
#  ('need', 8),
#  ('plate', 7),
#  ('mum', 7),
#  ('juice', 7),
#  ('cake', 7),
#  ('thankyou', 7),
#  ('car', 6),
#  ('youre', 6),
#  ('theyre', 6),
#  ('gonna', 6),
#  ('round', 6),
#  ('hafta', 5),
#  ('grapes', 5),
#  ('helicopter', 5),
#  ('doing', 5),
#  ('hello', 5),
#  ('goes', 5),
#  ('didnt', 5),
#  ('rabbit', 5),
#  ('um', 4),
#  ('mom', 4),
#  ('drink', 4),
#  ('ive', 4),
#  ('dog', 4),
#  ('open', 4),
#  ('cow', 4),
#  ('yum', 4),
#  ('girl', 4),
#  ('ill', 4),
#  ('heres', 4),
#  ('wow', 3),
#  ('way', 3),
#  ('having', 3),
#  ('hot', 3),
#  ('remember', 3),
#  ('yesterday', 3),
#  ('squirrel', 3),
#  ('bye', 3),
#  ('cup', 3),
#  ('food', 3),
#  ('box', 3),
#  ('pink', 3),
#  ('cut', 3),
#  ('poo', 3),
#  ('ah', 3),
#  ('nice', 3),
#  ('fit', 3),
#  ('woof', 3),
#  ('baby', 3),
#  ('time', 3),
#  ('alright', 3),
#  ('ooh', 2),
#  ('hm', 2),
#  ('monkey', 2),
#  ('apple', 2),
#  ('pretend', 2),
#  ('toilet', 2),
#  ('shes', 2),
#  ('cheese', 2),
#  ('engine', 2),
#  ('pull', 2),
#  ('needs', 2),
#  ('tree', 2),
#  ('gone', 2),
#  ('daddy', 2),
#  ('road', 2),
#  ('bubbly', 2),
#  ('orange', 2),
#  ('called', 2),
#  ('wine', 2),
#  ('teapot', 2),
#  ('fly', 2),
#  ('pizza', 2),
#  ('bedroom', 2),
#  ('neenaw', 2),
#  ('tractor', 2),
#  ('animals', 2),
#  ('tell', 2),
#  ('doggy', 2),
#  ('order', 2),
#  ('ambulance', 2),
#  ('things', 2),
#  ('lots', 2),
#  ('breakfast', 2),
#  ('bigger', 2),
#  ('hey', 2),
#  ('fruit', 2),
#  ('umm', 1),
#  ('rubbish', 1),
#  ('knock', 1),
#  ('daniel', 1),
#  ('suki', 1),
#  ('la', 1),
#  ('thing', 1),
#  ('giddy', 1),
#  ('angel', 1),
#  ('princess', 1),
#  ('dragon', 1),
#  ('funny', 1),
#  ('trot', 1),
#  ('doesnt', 1),
#  ('goats', 1),
#  ('allgone', 1),
#  ('charlie', 1),
#  ('belly', 1),
#  ('ache', 1),
#  ('boy', 1),
#  ('teddy', 1),
#  ('lady', 1),
#  ('phone', 1),
#  ('meow', 1),
#  ('favorite', 1),
#  ('works', 1),
#  ('started', 1),
#  ('crash', 1),
#  ('blue', 1),
#  ('green', 1),
#  ('holiday', 1),
#  ('wrong', 1),
#  ('hungry', 1),
#  ('peas', 1),
#  ('playgroup', 1),
#  ('callum', 1),
#  ('toast', 1),
#  ('trousers', 1),
#  ('harry', 1),
#  ('birthday', 1),
#  ('nellie', 1),
#  ('nellies', 1),
#  ('tower', 1),
#  ('faye', 1),
#  ('ones', 1),
#  ('zoo', 1),
#  ('park', 1),
#  ('sit', 1),
#  ('hop', 1),
#  ('nanny', 1),
#  ('turtle', 1),
#  ('dig', 1),
#  ('nut', 1),
#  ('home', 1),
#  ('birt', 1),
#  ('farm', 1),
#  ('moo', 1),
#  ('sure', 1),
#  ('small', 1),
#  ('chick', 1),
#  ('really', 1),
#  ('mouth', 1),
#  ('bear', 1),
#  ('aswell', 1),
#  ('live', 1),
#  ('slide', 1),
#  ('yellow', 1),
#  ('maybe', 1),
#  ('milk', 1),
#  ('maddie', 1),
#  ('school', 1),
#  ('celery', 1),
#  ('bacon', 1),
#  ('try', 1),
#  ('leave', 1),
#  ('away', 1),
#  ('mary', 1),
#  ('horsie', 1),
#  ('friends', 1),
#  ('people', 1),
#  ('jack', 1),
#  ('evie', 1),
#  ('poorly', 1),
#  ('horse', 1),
#  ('dogs', 1),
#  ('doctor', 1),
#  ('wedding', 1),
#  ('er', 1),
#  ('hotel', 1),
#  ('room', 1),
#  ('lettuce', 1),
#  ('today', 1),
#  ('dummy', 1),
#  ('went', 1),
#  ('making', 1),
#  ('wheels', 1),
#  ('stuff', 1),
#  ('boat', 1),
#  ('telling', 1),
#  ('hhh', 1),
#  ('gotta', 1),
#  ('rub', 1),
#  ('sugar', 1),
#  ('plates', 1),
#  ('howabout', 1),
#  ('awake', 1),
#  ('mat', 1),
#  ('bits', 1),
#  ('carrot', 1),
#  ('table', 1),
#  ('sandwich', 1),
#  ('girls', 1),
#  ('chop', 1),
#  ('steak', 1),
#  ('knight', 1),
#  ('needta', 1),
#  ('brave', 1),
#  ('sleep', 1),
#  ('eaten', 1),
#  ('dinner', 1),
#  ('awe', 1),
#  ('crisps', 1),
#  ('tickle', 1),
#  ('ready', 1),
#  ('chocolate', 1),
#  ('billy', 1),
#  ('hide', 1),
#  ('creams', 1),
#  ('land', 1),
#  ('airport', 1)]

# %%
# If more than half of the files have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 17]
add_stop_words
# Out:
# ['yeah',
#  'thats',
#  'look',
#  'oh',
#  'like',
#  'got',
#  'dont',
#  'xxx',
#  'going',
#  'whats',
#  'think',
#  'okay',
#  'yes',
#  'theres',
#  'know',
#  'did',
#  'im',
#  'big',
#  'play',
#  'want']

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('data_clean_to.pkl')

# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop_to.pkl", "wb"))
data_stop.to_pickle("dtm_stop_to.pkl")

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 10]


# Create subplots for each file
for index, file in enumerate(data.columns):
    wc.generate(data_clean.transcript[file])
    
    plt.subplot(10, 5, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(file)
    
plt.show()

# %% [markdown]
# ## Finding
# still some meaningless words, need to improve

# %% [markdown]
# ## EDA goal
# Our EDA goal is to take a first look if our basic analysis make sense.
# Still need to improve of course, but it's good enough to go further with this!
#
# "data science process is an interative one. It's better to see some non-perfect but acceptable results to help you quickly decide whether your project is a dud or not, instead of having analysis paralysis and never delivering anything."
#
# ref: [https://github.com/adashofdata/nlp-in-python-tutorial/blob/master/2-Exploratory-Data-Analysis.ipynb]
